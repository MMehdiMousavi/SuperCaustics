# %% [markdown]
# # Imports

# %% [markdown]
# This Notebook is sequentially processing Images from AIP to be used in Cleargrasp Training.
# The Code currently does not check for many things that can go wrong during copy-pasting data, so definitely make backups from your images before running this.

# %%
import numpy as np
import imageio
import PIL.Image as Image
import io
import os
from glob import glob
import shutil
import cv2
import cupy as cp

# %%
from tqdm.notebook import tqdm

# %%
imageio.plugins.freeimage.download()

# %% [markdown]
# # Make Dataset Folders

# %%
#point this to the RAW Screenshots folder. Make Backups before running.
os.chdir('E:/')
dir_src = ('E:/Dataset/Dataset/Train5K/')

Depth =   (dir_src + "/Depth/")
Normal = (dir_src + "/Normal/")
Pic =     (dir_src + "/Picture/")
Caustic = (dir_src + "/Picture_No_Caustic/")

Outlines = (dir_src + "/Outlines/")
Outlines_Processed = (dir_src + "/Outlines_Processed/")

Seg = (dir_src + "/Seg/")
Seg_Processed = (dir_src + "/Seg_Processed/")

Depth_exr =   (dir_src + "/Depth_exr/")
Normal_exr = (dir_src + "/Normal_exr/")
Seg_exr = (dir_src + "/Seg_exr/")

try:
    os.mkdir(Depth)
    os.mkdir(Normal)
    os.mkdir(Pic)
    os.mkdir(Caustic)
    os.mkdir(Outlines)
    os.mkdir(Seg)
    
    os.mkdir(Outlines_Processed)
    os.mkdir(Seg_Processed)
    
    os.mkdir(Depth_exr)
    os.mkdir(Normal_exr)
    os.mkdir(Seg_exr)

except OSError:
        print('Directory not created.')

# %% [markdown]
# # Move images into their respective folders (Order is important)

# %% [markdown]
# Use the Same order as you did when capturing your data from AIP SuperCaustics. In my case, I did this in the following order.

# %%
counter = 1
for filename in os.listdir(dir_src):

    if counter == 1:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Pic)
            print("moved " + filename, end='\r')
            counter = counter+1
            
    elif counter == 2:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Caustic)
            print("moved " + filename, end='\r')
            counter = counter+1

    elif counter == 3:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Depth) #Depth
            print("moved " + filename, end='\r')
            counter = counter+1

    elif counter == 4:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Normal) #Normal
            print("moved " + filename, end='\r')
            counter = counter+1
            
    elif counter == 5:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Outlines) #Outlines
            print("moved " + filename, end='\r')
            counter = counter+1

    elif counter == 6:
        if filename.endswith('.png'):
            shutil.move(dir_src + filename, Seg) #Seg
            print("moved " + filename, end='\r')
            counter = 1
# Out:
# moved HighresScreenshot00568.png
# moved HighresScreenshot01177.png
# moved HighresScreenshot01784.png
# moved HighresScreenshot02393.png
# moved HighresScreenshot03000.png
# moved HighresScreenshot03593.png
# moved HighresScreenshot04196.png
# moved HighresScreenshot04822.png
# moved HighresScreenshot05433.png
# moved HighresScreenshot06062.png
# moved HighresScreenshot06669.png
# moved HighresScreenshot07280.png
# moved HighresScreenshot07895.png
# moved HighresScreenshot08485.png
# moved HighresScreenshot09093.png
# moved HighresScreenshot09686.png
# moved HighresScreenshot10250.png
# moved HighresScreenshot10817.png
# moved HighresScreenshot11386.png
# moved HighresScreenshot11948.png
# moved HighresScreenshot12568.png
# moved HighresScreenshot13194.png
# moved HighresScreenshot13772.png
# moved HighresScreenshot14323.png
# moved HighresScreenshot14929.png
# moved HighresScreenshot15462.png
# moved HighresScreenshot15999.png
# moved HighresScreenshot16584.png
# moved HighresScreenshot17179.png
# moved HighresScreenshot17795.png
# moved HighresScreenshot18340.png
# moved HighresScreenshot18923.png
# moved HighresScreenshot19512.png
# moved HighresScreenshot20065.png
# moved HighresScreenshot20683.png
# moved HighresScreenshot21290.png
# moved HighresScreenshot21851.png
# moved HighresScreenshot22423.png
# moved HighresScreenshot23053.png
# moved HighresScreenshot23665.png
# moved HighresScreenshot24262.png
# moved HighresScreenshot24829.png
# moved HighresScreenshot25407.png
# moved HighresScreenshot25955.png
# moved HighresScreenshot26418.png
# moved HighresScreenshot26914.png
# moved HighresScreenshot27477.png
# moved HighresScreenshot27927.png
# moved HighresScreenshot28454.png
# moved HighresScreenshot29022.png
# moved HighresScreenshot29561.png
# moved HighresScreenshot30110.png
# moved HighresScreenshot30629.png

# %% [markdown]
# # Rename raw images in each folder to have the same name

# %%
i = 0
for filename in os.listdir(Pic):
    os.rename(Pic + '/' + filename, Pic + '/' + str(i) + '.png')
    i = i + 1
    print("renamed " + filename, end='\r')
    
v = 0
for filename in os.listdir(Caustic):
    os.rename(Caustic + '/' + filename, Caustic + '/' + str(v) + '.png')
    v = v + 1
    print("renamed " + filename, end='\r')

j = 0
for filename in os.listdir(Depth):
    os.rename(Depth + '/' + filename, Depth + '/' + str(j) + '.png')
    j = j + 1
    print("renamed " + filename, end='\r')

k = 0
for filename in os.listdir(Normal):
    os.rename(Normal + '/' + filename, Normal + '/' + str(k) + '.png')
    k = k + 1
    print("renamed " + filename, end='\r')
    
l = 0
for filename in os.listdir(Outlines):
    os.rename(Outlines + '/' + filename, Outlines + '/' + str(l) + '.png')
    l = l + 1
    print("renamed " + filename, end='\r')
    
m = 0
for filename in os.listdir(Seg):
    os.rename(Seg + '/' + filename, Seg + '/' + str(m) + '.png')
    m = m + 1
    print("renamed " + filename, end='\r')
# Out:
# renamed HighresScreenshot05538.png
# renamed HighresScreenshot11466.png
# renamed HighresScreenshot17184.png
# renamed HighresScreenshot23622.png
# renamed HighresScreenshot30120.png
# renamed HighresScreenshot05065.png
# renamed HighresScreenshot10825.png
# renamed HighresScreenshot16657.png
# renamed HighresScreenshot22573.png
# renamed HighresScreenshot29227.png
# renamed HighresScreenshot04670.png
# renamed HighresScreenshot11228.png
# renamed HighresScreenshot17786.png
# renamed HighresScreenshot24206.png
# renamed HighresScreenshot30626.png
# renamed HighresScreenshot05853.png
# renamed HighresScreenshot11859.png
# renamed HighresScreenshot17739.png
# renamed HighresScreenshot23691.png
# renamed HighresScreenshot29553.png
# renamed HighresScreenshot04174.png
# renamed HighresScreenshot08890.png
# renamed HighresScreenshot14764.png
# renamed HighresScreenshot20752.png
# renamed HighresScreenshot26638.png
# renamed HighresScreenshot01577.png
# renamed HighresScreenshot07337.png
# renamed HighresScreenshot13145.png
# renamed HighresScreenshot16889.png
# renamed HighresScreenshot22445.png
# renamed HighresScreenshot28043.png
# renamed HighresScreenshot30629.png

# %% [markdown]
# # Seg & Outlines should be L.

# %%
for filename in os.listdir(Seg):
    segaddress = Seg + filename
    newaddress = Seg_Processed + filename
    img = []
    arr = np.array(Image.open(segaddress).convert('L'))
    img = np.where(arr>= 220, 255,-1)
    cv2.imwrite(newaddress, img)
    print(filename + 'Processed.', end='\r')
    
print('Seg Files Processed.')


for filename in os.listdir(Outlines):
    outaddress = Outlines + filename
    newaddress = Outlines_Processed + filename
    image = Image.open(outaddress)
    image = image.convert('L')
    arr = np.asarray(image)
    arr = np.floor(arr/126)
    cv2.imwrite(newaddress, arr)
    print(filename + 'Processed.', end='\r')
    
print('Outline Files Processed.')
# Out:
# Seg Files Processed.
# Outline Files Processed.

# %% [markdown]
# # Converting To EXR for Cleargrasp

# %% [markdown]
# Cleargrasp uses .EXR files as Ground Truth extension. This step is not required if youre not using EXR format.

# %%
for filename in os.listdir(Depth):
    address = Depth + filename
    newaddress = Depth_exr + filename
    image = Image.open(address)
    arr = np.asarray(image)
    arr = arr.astype("float32")
    imageio.imwrite(newaddress.replace('.png','.exr'), arr)
    print(filename + ' Processed.', end='\r')

print('Depth EXRs Created.')
    
for filename in os.listdir(Normal):
    address = Normal + filename
    newaddress = Normal_exr + filename
    image = Image.open(address)
    arr = np.asarray(image)
    arr = arr.astype("float32")
    imageio.imwrite(newaddress.replace('.png','.exr'), arr)
    print(filename + ' Processed.', end='\r')
    
print('Normal EXRs Created.')
    
for filename in os.listdir(Seg_Processed):
    address = Seg + filename
    newaddress = Seg_exr + filename
    image = Image.open(address)
    arr = np.asarray(image)
    arr = arr.astype("float32")
    imageio.imwrite(newaddress.replace('.png','.exr'), arr)
    print(filename + ' Processed.', end='\r')
    
print('Seg EXRs Created.')
# Out:
# Depth EXRs Created.
# Normal EXRs Created.
# Seg EXRs Created...

# %% [markdown]
# # Choosing a Random Validation Set

# %%
import random


#point this to the RAW Screenshots folder. Make Backups before running.
dir_val = ('E:/Dataset/Dataset/Train5K_val/')

valDepth =   (dir_val + "/Depth/")
valNormal = (dir_val + "/Normal/")
valPic =     (dir_val + "/Picture/")
valCaustic = (dir_val + "/Picture_No_Caustic/")

valOutlines = (dir_val + "/Outlines/")
valOutlines_Processed = (dir_val + "/Outlines_Processed/")

valSeg = (dir_val + "/Seg/")
valSeg_Processed = (dir_val + "/Seg_Processed/")

valDepth_exr =   (dir_val + "/Depth_exr/")
valNormal_exr = (dir_val + "/Normal_exr/")
valSeg_exr = (dir_val + "/Seg_exr/")

try:
    os.mkdir(valDepth)
    os.mkdir(valNormal)
    os.mkdir(valPic)
    os.mkdir(valCaustic)
    os.mkdir(valOutlines)
    os.mkdir(valSeg)
    
    os.mkdir(valOutlines_Processed)
    os.mkdir(valSeg_Processed)
    
    os.mkdir(valDepth_exr)
    os.mkdir(valNormal_exr)
    os.mkdir(valSeg_exr)

except OSError:
        print('Directory not created.')
